# %% [markdown]
# This notebook handles:
# 1. Creating Elastis Search Index
# 2. Uploading data to the index

# %% [markdown]
# - Google Maps uses lat,lon
# - spatial context uses lon,lat

# %% [markdown]
# Importing Libraries

# %%
import os
import json
from bs4 import BeautifulSoup
from elasticsearch import Elasticsearch
import spacy
from geopy.geocoders import Nominatim
from datetime import datetime

## These are used to re-connect to geocoder when max limit is reached
from geopy.exc import GeocoderTimedOut
# from geopy.exc import GeocoderUnavailable
# from requests.exceptions import ConnectionError
# import time

# %% [markdown]
# Creating an Index

# %%
# Elasticsearch configuration
es = Elasticsearch([{'host':'localhost','port':9200,'scheme':'http'}])
index_name = 'reut2'

# %%
# Define the mapping and settings
mapping = {
    "mappings": {
        "properties": {
            "date": {"type": "date"},
            "author": {"type": "text"},
            "title": {
                 "type" : "text",
                 "analyzer":"autocomplete"
            },
            
            "body": {
                "type": "text",
                "analyzer": "custom_analyzer"
                },
            "temporal_expressions": {
                "type": "nested",
                "properties": {
                    "text": {"type": "text"},
                    "label": {"type": "text"},
                }
            },
            "georeferences": {
                "type": "nested",
                "properties": {
                    "location": {"type": "keyword"},
                    "coordinates": {"type": "geo_point"},
                }
            },
            "geopoint_author": {
                "type": "nested",
                "properties": {
                    "location": {"type": "text"},
                    "coordinates": {"type": "geo_point"},
                }
            },
            #  "avg_geopoint": {
            #     "type": "nested",
            #     "properties": {
            #         "location": {"type": "text"},
            #         "coordinates": {"type": "geo_point"},
            #     }
            # },
        }
    },
    "settings": {
        "analysis": {
            "analyzer": {
                "autocomplete": {
                    "type": "custom",
                    "tokenizer": "autocomplete_tokenizer",
                    "filter": [
                        "lowercase",
                        "autocomplete_filter",
                        "shingle_filter"
                    ]
                },
                "custom_analyzer": {
                    "type": "custom",
                    "tokenizer": "standard",
                    "filter": ["lowercase", "stop", "stemmer"],
                },
            },
            "tokenizer": {
                "autocomplete_tokenizer": {
                    "type": "edge_ngram",
                    "min_gram": 1,
                    "max_gram": 20,
                    "token_chars": ["letter", "digit"]
                },
            },
            "filter": {
                "autocomplete_filter": {
                    "type": "edge_ngram",
                    "min_gram": 1,
                    "max_gram": 20
                },
                "shingle_filter": {
                    "type": "shingle",
                    "min_shingle_size": 2,
                    "max_shingle_size": 4
                },
            },
        },
    },
}
 
# Create the index with the mapping and settings
es.indices.create(index=index_name, body=mapping, ignore=400)
# Out:
# C:\Users\farah\AppData\Local\Temp/ipykernel_27388/1376067338.py:89: DeprecationWarning: Passing transport options in the API method is deprecated. Use 'Elasticsearch.options()' instead.
#   es.indices.create(index=index_name, body=mapping, ignore=400)
# ObjectApiResponse({'acknowledged': True, 'shards_acknowledged': True, 'index': 'reut2'})

# %% [markdown]
# Tracking the last file and line parsed

# %%
def get_last_parsed_info():
    """
    Function to read and return the last parsed file and line.

    Returns:
        Tuple[str, int]: A tuple containing the last parsed file and line number.
                        If no information is available, returns (None, 0).
    """
    file_path = "D:/4th year 1st semester/IR/Project/cache/last_parsed_info.txt"
    try:
        with open(file_path, "r") as file:
            content = file.readline().strip()
            if content:
                last_parsed_info = content.split(",")
                if len(last_parsed_info) == 2:
                    last_parsed_file, last_parsed_line = last_parsed_info
                    last_parsed_line = int(last_parsed_line)
                else:
                    last_parsed_file = None
                    last_parsed_line = 0
            else:
                last_parsed_file = None
                last_parsed_line = 0
    except FileNotFoundError:
        # If the file is not found, create a new file
        with open(file_path, "w") as file:
            last_parsed_file = None
            last_parsed_line = 0
    return last_parsed_file, last_parsed_line



def write_last_parsed_info(file_name, line_number):
    """
    Function to write the last parsed file and line to the file.

    Args:
        file_name (str): The name of the last parsed file.
        line_number (int): The line number in the last parsed file.
    """
    file_path = "D:/4th year 1st semester/IR/Project/cache/last_parsed_info.txt"
    with open(file_path, "w") as file:
        file.write(f"{file_name},{line_number}")

# %% [markdown]
# Functions to extract geopoints, georeferences, and temporal expressions.
#
# **Cashing concept is used here**

# %%
# Initialize the geopy geocoder
geolocator = Nominatim(user_agent="tri-3")

# Initialize spacy for extracting georeferences
nlp = spacy.load("en_core_web_sm")

# File paths for saving data
cache_directory = 'D:/4th year 1st semester/IR/Project/cache/'
reuters_info_json_path = os.path.join(cache_directory, 'reuters_info.json')
geopoints_file_path = os.path.join(cache_directory, 'geopoints.csv')

# Create the cache directory if it does not exist
os.makedirs(cache_directory, exist_ok=True)



def extract_geopoints(location,attempt=1, max_attempts=5):
    """
    Function to extract geopoints (latitude, longitude) for a given location.

    Args:
        location (str): The location to extract geopoints for.

    Returns:
        Union[Dict[str, Union[str, Dict[str, float]]], int]: 
            If geopoints are found, returns a dictionary containing the location and coordinates.
            If not found, returns 0.
    """

    processed_locations = []
    location=location.replace(",","")


    # Check if the location is already processed
    if os.path.exists(geopoints_file_path):
        with open(geopoints_file_path, 'r') as geopoints_file:
            for line in geopoints_file:
                parts = line.strip().split(',')
                if len(parts) >= 3:
                    saved_location, lat, lon = parts[0].strip().lower(), parts[1], parts[2]
                    if lat and lon:
                        processed_locations.append({"location": saved_location, "coordinates": {"lat": float(lat), "lon": float(lon)}})
                    

    # Normalize the location to lowercase
    normalized_location = location.strip().lower()

    # Check if the location is already processed
    for geopoint in processed_locations:
        if normalized_location == geopoint["location"]:
            return {"location": normalized_location, "coordinates": geopoint['coordinates']}

    # If not already processed, use geopy to get lon, lat
    try:
        geocoded_location = geolocator.geocode(normalized_location, timeout=None)
        if geocoded_location and geocoded_location.longitude and geocoded_location.latitude:
            lon, lat = geocoded_location.longitude, geocoded_location.latitude
            if lat and lon:
                with open(geopoints_file_path, 'a') as geopoints_file:
                    geopoints_file.write(f'{normalized_location},{float(lat)},{float(lon)}\n')

                return {"location": normalized_location, "coordinates": {"lat": float(lat), "lon": float(lon)}}
            else:
                return 0
    except GeocoderTimedOut:
        if attempt <= max_attempts:
            return extract_geopoints(normalized_location, attempt=attempt+1)





def extract_georeferences(body):
    """
    Function to extract georeferences from the given text body.

    Args:
        body (str): The text body to extract georeferences from.

    Returns:
        List[Dict[str, Union[str, Dict[str, Union[str, float]]]]]: A list of dictionaries containing
        the extracted georeferences and their coordinates.
    """
    doc = nlp(body)
    georefs = []

    for ent in doc.ents:
        if ent.label_ in ['GPE', 'LOC']:
            results = extract_geopoints(ent.text)
            if results != 0:
                if results and results not in georefs:
                    georefs.append(results)

    return georefs





def extract_temporal_expressions(text):
    """
    Function to extract temporal expressions from the given text.

    Args:
        text (str): The text to extract temporal expressions from.

    Returns:
        List[Dict[str, str]]: A list of dictionaries containing the extracted temporal expressions and their labels.
    """
    doc = nlp(text)
    temporal_expressions = []

    for ent in doc.ents:
        if ent.label_ in ["DATE", "TIME"]:
            temporal_expressions.append({
                "text": ent.text,
                "label": ent.label_
            })

    return temporal_expressions

# %% [markdown]
# This function was used to get the reversed location for an average georeferences point, but after testing, the idea is not valid to use.
#
#  (NOT USED IN THE LAST VERSION)

# %%
# from geopy.exc import GeocoderTimedOut

# def reverse_geocode(lon, lat):
#     """
#     Function to perform reverse geocoding, converting coordinates (longitude, latitude) to a human-readable address.

#     Args:
#         lon (float): The longitude of the location.
#         lat (float): The latitude of the location.

#     Returns:
#         str or None: The human-readable address if successfully reverse geocoded, or None if a timeout occurs.
#     """
#     try:
#         location = geolocator.reverse((lat, lon), language='en')
#         print("location: ", location)
#         return location.address
#     except GeocoderTimedOut:
#         return None

# %% [markdown]
# This is the main function, it handles:
# 1. Reading and parsing the files.
# 2. Extract "date, authors, title, body" from the files directly.
# 3. Calling the functions to extract geopoint (fromm date line and places), georeferences (using body), and temporal expressions (from body).
# 4. Data are saved as JSON objects in a file.

# %%
def extract_reuters_info(folder_path):
    """
    Function to extract information from Reuters files in a given folder and store it in a JSON file.

    Args:
        folder_path (str): The path to the folder containing Reuters files.
    """
  
    for file_name in os.listdir(folder_path):
        
        if file_name.endswith('.sgm'):
            file_path = os.path.join(folder_path, file_name)
            with open(file_path, 'r', encoding='latin-1') as file:
                content = file.readlines()

            soup = BeautifulSoup("".join(content), 'html.parser')

            total=len(soup.find_all('reuters'))

            for i, reuters_tag in enumerate(soup.find_all('reuters')):

                # Get the last parsed file and line
                last_parsed_file, last_parsed_line = get_last_parsed_info()
                
                if last_parsed_file is not None:
                    current_file_number = int(file_name[6:9])
                    last_parsed_file_number = int(last_parsed_file[6:9])

                    if current_file_number < last_parsed_file_number:
                        break  # Skip files that have already been processed

                    if current_file_number == last_parsed_file_number and i <= last_parsed_line:
                        continue  # Skip lines that have already been processed
                    
                date_string = reuters_tag.find('date').text.strip() if reuters_tag.find('date') else ''
                input_date = datetime.strptime(date_string, '%d-%b-%Y %H:%M:%S.%f')
                formatted_date = input_date.strftime('%Y-%m-%dT%H:%M:%S.%fZ')
                reuters_info = {
                    'date': formatted_date,
                    'authors': reuters_tag.find('author').text.strip() if reuters_tag.find('author') else 'ANONYMOUS',
                    'title': reuters_tag.find('title').text.strip() if reuters_tag.find('title') else '',
                    'body': reuters_tag.find('body').text.strip() if reuters_tag.find('body') else 0
                }

                #if "body" is empty, ignore the file
                if reuters_info['body'] == 0:
                    continue

                
                # Extract additional information
                reuters_info['geopoint_author'] = extract_geopoints(reuters_tag.find('dateline').text.strip().split()[0].replace(',', '') if reuters_tag.find('dateline') else '')
                reuters_info['temporal_expressions'] = extract_temporal_expressions(reuters_info['body'])
                reuters_info['georeferences'] = extract_georeferences(reuters_info['body'])
                places = [place.text.strip() for place in reuters_tag.find('places').find_all('d')] if reuters_tag.find('places') else []
                geopoints = [extract_geopoints(place) for place in places if extract_geopoints(place) != 0]
                reuters_info['geopoint_author'] = geopoints
                

                # This was used to compute an average geo-point for georeferences, but the results are not valid.
                 
                # if(reuters_info['georeferences']):
                #     if (len(reuters_info['georeferences'])>1):
                #         # Calculate the average latitude and longitude
                #         geopoints = reuters_info['georeferences']
                #         print(geopoints)
                #         if geopoints:
                #             sum_lon=0
                #             sum_lat=0
                #             dom=len(geopoints)
                            
                #             for point in geopoints:  
                #                 print(type(float(point['coordinates']['lon'])))
                #                 sum_lon += float(point['coordinates']['lon'])
                #                 sum_lat += float(point['coordinates']['lat'])

                #             avg_lon=sum_lon/dom
                #             avg_lat=sum_lat/dom
                #             avg_geopoint = {"coordinates": {"lat": avg_lat, "lon": avg_lon}}
                #             print("avgp: ",avg_geopoint)

                #             # Reverse geocode to get an estimated location name
                #             estimated_location_name = reverse_geocode(avg_lon, avg_lat)
                #             if estimated_location_name:
                #                 avg_geopoint['location'] = estimated_location_name      
                #                 reuters_info['avg_geopoint'] = avg_geopoint
                #             else: 
                #                 reuters_info['avg_geopoint'] = reuters_info['georeferences']


                # Save reuters info to JSON file
                with open(reuters_info_json_path, 'a') as json_file:
                    json.dump(reuters_info, json_file, indent=2)
                    json_file.write(',\n')

                # Update the tracking of file and line
                write_last_parsed_info(file_name, i)

    # Check if the end of the file is reached
    if i == total:
        # Reset the line number to 0 if the end of the file is reached
        write_last_parsed_info(file_name, 0)
        print(f"Updated last parsed info for {file_name}:0")

# Folder path
folder_path = "D:/4th year 1st semester/IR/Project/data"

# Extracting
extract_reuters_info(folder_path)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27388/2731491507.py in <module>
#     106
#     107 # Extracting
# --> 108 extract_reuters_info(folder_path)
#
# ~\AppData\Local\Temp/ipykernel_27388/2731491507.py in extract_reuters_info(folder_path)
#      34
#      35                 date_string = reuters_tag.find('date').text.strip() if reuters_tag.find('date') else ''
# ---> 36                 input_date = datetime.strptime(date_string, '%d-%b-%Y %H:%M:%S.%f')
#      37                 formatted_date = input_date.strftime('%Y-%m-%dT%H:%M:%S.%fZ')
#      38                 reuters_info = {
#
# c:\Users\farah\anaconda3\lib\_strptime.py in _strptime_datetime(cls, data_string, format)
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# c:\Users\farah\anaconda3\lib\_strptime.py in _strptime(data_string, format)
#     350                          (data_string, format))
#     351     if len(data_string) != found.end():
# --> 352         raise ValueError("unconverted data remains: %s" %
#     353                           data_string[found.end():])
#     354
#
# ValueError: unconverted data remains: RM

# %% [markdown]
# Inserting JSON objects to the elastic search index

# %%
# Specify the index name
index_name = 'reut2'

# Read the JSON file
with open('D:/4th year 1st semester/IR/Project/cache/reuters_info.json', 'r') as file:
    json_data = file.read()

# Parse the JSON data into a list of dictionaries
try:
    documents = json.loads(json_data)
except json.JSONDecodeError as e:
    print(f"Error decoding JSON: {e}")
    documents = []

# Insert each document into the Elasticsearch index
for idx, document in enumerate(documents, start=1):
    try:
        # Insert the document into the Elasticsearch index
        es.index(index=index_name, id=idx, body=document)
        print(f"Inserted document {idx} into the '{index_name}' index.")
    except Exception as e:
        print(f"Error inserting document {idx}: {e}")

# Refresh the index to make the documents searchable immediately 
es.indices.refresh(index=index_name)
# Out:
# Inserted document 1 into the 'reut2' index.
# Inserted document 2 into the 'reut2' index.
# Inserted document 3 into the 'reut2' index.
# Inserted document 4 into the 'reut2' index.
# Inserted document 5 into the 'reut2' index.
# Inserted document 6 into the 'reut2' index.
# Inserted document 7 into the 'reut2' index.
# Inserted document 8 into the 'reut2' index.
# Inserted document 9 into the 'reut2' index.
# Inserted document 10 into the 'reut2' index.
# Inserted document 11 into the 'reut2' index.
# Inserted document 12 into the 'reut2' index.
# Inserted document 13 into the 'reut2' index.
# Inserted document 14 into the 'reut2' index.
# Inserted document 15 into the 'reut2' index.
# Inserted document 16 into the 'reut2' index.
# Inserted document 17 into the 'reut2' index.
# Inserted document 18 into the 'reut2' index.
# Inserted document 19 into the 'reut2' index.
# Inserted document 20 into the 'reut2' index.
# Inserted document 21 into the 'reut2' index.
# Inserted document 22 into the 'reut2' index.
# Inserted document 23 into the 'reut2' index.
# Inserted document 24 into the 'reut2' index.
# Inserted document 25 into the 'reut2' index.
# Inserted document 26 into the 'reut2' index.
# Inserted document 27 into the 'reut2' index.
# Inserted document 28 into the 'reut2' index.
# Inserted document 29 into the 'reut2' index.
# Inserted document 30 into the 'reut2' index.
# Inserted document 31 into the 'reut2' index.
# Inserted document 32 into the 'reut2' index.
# Inserted document 33 into the 'reut2' index.
# Inserted document 34 into the 'reut2' index.
# Inserted document 35 into the 'reut2' index.
# Inserted document 36 into the 'reut2' index.
# Inserted document 37 into the 'reut2' index.
# Inserted document 38 into the 'reut2' index.
# Inserted document 39 into the 'reut2' index.
# Inserted document 40 into the 'reut2' index.
# Inserted document 41 into the 'reut2' index.
# Inserted document 42 into the 'reut2' index.
# Inserted document 43 into the 'reut2' index.
# Inserted document 44 into the 'reut2' index.
# Inserted document 45 into the 'reut2' index.
# Inserted document 46 into the 'reut2' index.
# Inserted document 47 into the 'reut2' index.
# Inserted document 48 into the 'reut2' index.
# Inserted document 49 into the 'reut2' index.
# Inserted document 50 into the 'reut2' index.
# Inserted document 51 into the 'reut2' index.
# Inserted document 52 into the 'reut2' index.
# Inserted document 53 into the 'reut2' index.
# Inserted document 54 into the 'reut2' index.
# Inserted document 55 into the 'reut2' index.
# Inserted document 56 into the 'reut2' index.
# Inserted document 57 into the 'reut2' index.
# Inserted document 58 into the 'reut2' index.
# Inserted document 59 into the 'reut2' index.
# Inserted document 60 into the 'reut2' index.
# Inserted document 61 into the 'reut2' index.
# Inserted document 62 into the 'reut2' index.
# Inserted document 63 into the 'reut2' index.
# Inserted document 64 into the 'reut2' index.
# Inserted document 65 into the 'reut2' index.
# Inserted document 66 into the 'reut2' index.
# Inserted document 67 into the 'reut2' index.
# Inserted document 68 into the 'reut2' index.
# Inserted document 69 into the 'reut2' index.
# Inserted document 70 into the 'reut2' index.
# Inserted document 71 into the 'reut2' index.
# Inserted document 72 into the 'reut2' index.
# Inserted document 73 into the 'reut2' index.
# Inserted document 74 into the 'reut2' index.
# Inserted document 75 into the 'reut2' index.
# Inserted document 76 into the 'reut2' index.
# Inserted document 77 into the 'reut2' index.
# Inserted document 78 into the 'reut2' index.
# Inserted document 79 into the 'reut2' index.
# Inserted document 80 into the 'reut2' index.
# Inserted document 81 into the 'reut2' index.
# Inserted document 82 into the 'reut2' index.
# Inserted document 83 into the 'reut2' index.
# Inserted document 84 into the 'reut2' index.
# Inserted document 85 into the 'reut2' index.
# Inserted document 86 into the 'reut2' index.
# Inserted document 87 into the 'reut2' index.
# Inserted document 88 into the 'reut2' index.
# Inserted document 89 into the 'reut2' index.
# Inserted document 90 into the 'reut2' index.
# Inserted document 91 into the 'reut2' index.
# Inserted document 92 into the 'reut2' index.
# Inserted document 93 into the 'reut2' index.
# Inserted document 94 into the 'reut2' index.
# Inserted document 95 into the 'reut2' index.
# Inserted document 96 into the 'reut2' index.
# Inserted document 97 into the 'reut2' index.
# Inserted document 98 into the 'reut2' index.
# Inserted document 99 into the 'reut2' index.
# Inserted document 100 into the 'reut2' index.
# Inserted document 101 into the 'reut2' index.
# Inserted document 102 into the 'reut2' index.
# Inserted document 103 into the 'reut2' index.
# Inserted document 104 into the 'reut2' index.
# Inserted document 105 into the 'reut2' index.
# Inserted document 106 into the 'reut2' index.
# Inserted document 107 into the 'reut2' index.
# Inserted document 108 into the 'reut2' index.
# Inserted document 109 into the 'reut2' index.
# Inserted document 110 into the 'reut2' index.
# Inserted document 111 into the 'reut2' index.
# Inserted document 112 into the 'reut2' index.
# Inserted document 113 into the 'reut2' index.
# Inserted document 114 into the 'reut2' index.
# Inserted document 115 into the 'reut2' index.
# Inserted document 116 into the 'reut2' index.
# Inserted document 117 into the 'reut2' index.
# Inserted document 118 into the 'reut2' index.
# Inserted document 119 into the 'reut2' index.
# Inserted document 120 into the 'reut2' index.
# Inserted document 121 into the 'reut2' index.
# Inserted document 122 into the 'reut2' index.
# Inserted document 123 into the 'reut2' index.
# Inserted document 124 into the 'reut2' index.
# Inserted document 125 into the 'reut2' index.
# Inserted document 126 into the 'reut2' index.
# Inserted document 127 into the 'reut2' index.
# Inserted document 128 into the 'reut2' index.
# Inserted document 129 into the 'reut2' index.
# Inserted document 130 into the 'reut2' index.
# Inserted document 131 into the 'reut2' index.
# Inserted document 132 into the 'reut2' index.
# Inserted document 133 into the 'reut2' index.
# Inserted document 134 into the 'reut2' index.
# Inserted document 135 into the 'reut2' index.
# Inserted document 136 into the 'reut2' index.
# Inserted document 137 into the 'reut2' index.
# Inserted document 138 into the 'reut2' index.
# Inserted document 139 into the 'reut2' index.
# Inserted document 140 into the 'reut2' index.
# Inserted document 141 into the 'reut2' index.
# Inserted document 142 into the 'reut2' index.
# Inserted document 143 into the 'reut2' index.
# Inserted document 144 into the 'reut2' index.
# Inserted document 145 into the 'reut2' index.
# Inserted document 146 into the 'reut2' index.
# Inserted document 147 into the 'reut2' index.
# Inserted document 148 into the 'reut2' index.
# Inserted document 149 into the 'reut2' index.
# Inserted document 150 into the 'reut2' index.
# Inserted document 151 into the 'reut2' index.
# Inserted document 152 into the 'reut2' index.
# Inserted document 153 into the 'reut2' index.
# Inserted document 154 into the 'reut2' index.
# Inserted document 155 into the 'reut2' index.
# Inserted document 156 into the 'reut2' index.
# Inserted document 157 into the 'reut2' index.
# Inserted document 158 into the 'reut2' index.
# Inserted document 159 into the 'reut2' index.
# Inserted document 160 into the 'reut2' index.
# Inserted document 161 into the 'reut2' index.
# Inserted document 162 into the 'reut2' index.
# Inserted document 163 into the 'reut2' index.
# Inserted document 164 into the 'reut2' index.
# Inserted document 165 into the 'reut2' index.
# Inserted document 166 into the 'reut2' index.
# Inserted document 167 into the 'reut2' index.
# Inserted document 168 into the 'reut2' index.
# Inserted document 169 into the 'reut2' index.
# Inserted document 170 into the 'reut2' index.
# Inserted document 171 into the 'reut2' index.
# Inserted document 172 into the 'reut2' index.
# Inserted document 173 into the 'reut2' index.
# Inserted document 174 into the 'reut2' index.
# Inserted document 175 into the 'reut2' index.
# Inserted document 176 into the 'reut2' index.
# Inserted document 177 into the 'reut2' index.
# Inserted document 178 into the 'reut2' index.
# Inserted document 179 into the 'reut2' index.
# Inserted document 180 into the 'reut2' index.
# Inserted document 181 into the 'reut2' index.
# Inserted document 182 into the 'reut2' index.
# Inserted document 183 into the 'reut2' index.
# Inserted document 184 into the 'reut2' index.
# Inserted document 185 into the 'reut2' index.
# Inserted document 186 into the 'reut2' index.
# Inserted document 187 into the 'reut2' index.
# Inserted document 188 into the 'reut2' index.
# Inserted document 189 into the 'reut2' index.
# Inserted document 190 into the 'reut2' index.
# Inserted document 191 into the 'reut2' index.
# Inserted document 192 into the 'reut2' index.
# Inserted document 193 into the 'reut2' index.
# Inserted document 194 into the 'reut2' index.
# Inserted document 195 into the 'reut2' index.
# Inserted document 196 into the 'reut2' index.
# Inserted document 197 into the 'reut2' index.
# Inserted document 198 into the 'reut2' index.
# Inserted document 199 into the 'reut2' index.
# Inserted document 200 into the 'reut2' index.
# Inserted document 201 into the 'reut2' index.
# Inserted document 202 into the 'reut2' index.
# Inserted document 203 into the 'reut2' index.
# Inserted document 204 into the 'reut2' index.
# Inserted document 205 into the 'reut2' index.
# Inserted document 206 into the 'reut2' index.
# Inserted document 207 into the 'reut2' index.
# Inserted document 208 into the 'reut2' index.
# Inserted document 209 into the 'reut2' index.
# Inserted document 210 into the 'reut2' index.
# Inserted document 211 into the 'reut2' index.
# Inserted document 212 into the 'reut2' index.
# Inserted document 213 into the 'reut2' index.
# Inserted document 214 into the 'reut2' index.
# Inserted document 215 into the 'reut2' index.
# Inserted document 216 into the 'reut2' index.
# Inserted document 217 into the 'reut2' index.
# Inserted document 218 into the 'reut2' index.
# Inserted document 219 into the 'reut2' index.
# Inserted document 220 into the 'reut2' index.
# Inserted document 221 into the 'reut2' index.
# Inserted document 222 into the 'reut2' index.
# Inserted document 223 into the 'reut2' index.
# Inserted document 224 into the 'reut2' index.
# Inserted document 225 into the 'reut2' index.
# Inserted document 226 into the 'reut2' index.
# Inserted document 227 into the 'reut2' index.
# Inserted document 228 into the 'reut2' index.
# Inserted document 229 into the 'reut2' index.
# Inserted document 230 into the 'reut2' index.
# Inserted document 231 into the 'reut2' index.
# Inserted document 232 into the 'reut2' index.
# Inserted document 233 into the 'reut2' index.
# Inserted document 234 into the 'reut2' index.
# Inserted document 235 into the 'reut2' index.
# Inserted document 236 into the 'reut2' index.
# Inserted document 237 into the 'reut2' index.
# Inserted document 238 into the 'reut2' index.
# Inserted document 239 into the 'reut2' index.
# Inserted document 240 into the 'reut2' index.
# Inserted document 241 into the 'reut2' index.
# Inserted document 242 into the 'reut2' index.
# Inserted document 243 into the 'reut2' index.
# Inserted document 244 into the 'reut2' index.
# Inserted document 245 into the 'reut2' index.
# Inserted document 246 into the 'reut2' index.
# Inserted document 247 into the 'reut2' index.
# Inserted document 248 into the 'reut2' index.
# Inserted document 249 into the 'reut2' index.
# Inserted document 250 into the 'reut2' index.
# Inserted document 251 into the 'reut2' index.
# Inserted document 252 into the 'reut2' index.
# Inserted document 253 into the 'reut2' index.
# Inserted document 254 into the 'reut2' index.
# Inserted document 255 into the 'reut2' index.
# Inserted document 256 into the 'reut2' index.
# Inserted document 257 into the 'reut2' index.
# Inserted document 258 into the 'reut2' index.
# Inserted document 259 into the 'reut2' index.
# Inserted document 260 into the 'reut2' index.
# Inserted document 261 into the 'reut2' index.
# Inserted document 262 into the 'reut2' index.
# Inserted document 263 into the 'reut2' index.
# Inserted document 264 into the 'reut2' index.
# Inserted document 265 into the 'reut2' index.
# Inserted document 266 into the 'reut2' index.
# Inserted document 267 into the 'reut2' index.
# Inserted document 268 into the 'reut2' index.
# Inserted document 269 into the 'reut2' index.
# Inserted document 270 into the 'reut2' index.
# Inserted document 271 into the 'reut2' index.
# Inserted document 272 into the 'reut2' index.
# Inserted document 273 into the 'reut2' index.
# Inserted document 274 into the 'reut2' index.
# Inserted document 275 into the 'reut2' index.
# Inserted document 276 into the 'reut2' index.
# Inserted document 277 into the 'reut2' index.
# Inserted document 278 into the 'reut2' index.
# Inserted document 279 into the 'reut2' index.
# Inserted document 280 into the 'reut2' index.
# Inserted document 281 into the 'reut2' index.
# Inserted document 282 into the 'reut2' index.
# Inserted document 283 into the 'reut2' index.
# Inserted document 284 into the 'reut2' index.
# Inserted document 285 into the 'reut2' index.
# Inserted document 286 into the 'reut2' index.
# Inserted document 287 into the 'reut2' index.
# Inserted document 288 into the 'reut2' index.
# Inserted document 289 into the 'reut2' index.
# Inserted document 290 into the 'reut2' index.
# Inserted document 291 into the 'reut2' index.
# Inserted document 292 into the 'reut2' index.
# Inserted document 293 into the 'reut2' index.
# Inserted document 294 into the 'reut2' index.
# Inserted document 295 into the 'reut2' index.
# Inserted document 296 into the 'reut2' index.
# Inserted document 297 into the 'reut2' index.
# Inserted document 298 into the 'reut2' index.
# Inserted document 299 into the 'reut2' index.
# Inserted document 300 into the 'reut2' index.
# Inserted document 301 into the 'reut2' index.
# Inserted document 302 into the 'reut2' index.
# Inserted document 303 into the 'reut2' index.
# Inserted document 304 into the 'reut2' index.
# Inserted document 305 into the 'reut2' index.
# Inserted document 306 into the 'reut2' index.
# Inserted document 307 into the 'reut2' index.
# Inserted document 308 into the 'reut2' index.
# Inserted document 309 into the 'reut2' index.
# Inserted document 310 into the 'reut2' index.
# Inserted document 311 into the 'reut2' index.
# Inserted document 312 into the 'reut2' index.
# Inserted document 313 into the 'reut2' index.
# Inserted document 314 into the 'reut2' index.
# Inserted document 315 into the 'reut2' index.
# Inserted document 316 into the 'reut2' index.
# Inserted document 317 into the 'reut2' index.
# Inserted document 318 into the 'reut2' index.
# Inserted document 319 into the 'reut2' index.
# Inserted document 320 into the 'reut2' index.
# Inserted document 321 into the 'reut2' index.
# Inserted document 322 into the 'reut2' index.
# Inserted document 323 into the 'reut2' index.
# Inserted document 324 into the 'reut2' index.
# Inserted document 325 into the 'reut2' index.
# Inserted document 326 into the 'reut2' index.
# Inserted document 327 into the 'reut2' index.
# Inserted document 328 into the 'reut2' index.
# Inserted document 329 into the 'reut2' index.
# Inserted document 330 into the 'reut2' index.
# Inserted document 331 into the 'reut2' index.
# Inserted document 332 into the 'reut2' index.
# Inserted document 333 into the 'reut2' index.
# Inserted document 334 into the 'reut2' index.
# Inserted document 335 into the 'reut2' index.
# Inserted document 336 into the 'reut2' index.
# Inserted document 337 into the 'reut2' index.
# Inserted document 338 into the 'reut2' index.
# Inserted document 339 into the 'reut2' index.
# Inserted document 340 into the 'reut2' index.
# Inserted document 341 into the 'reut2' index.
# Inserted document 342 into the 'reut2' index.
# Inserted document 343 into the 'reut2' index.
# Inserted document 344 into the 'reut2' index.
# Inserted document 345 into the 'reut2' index.
# Inserted document 346 into the 'reut2' index.
# Inserted document 347 into the 'reut2' index.
# Inserted document 348 into the 'reut2' index.
# Inserted document 349 into the 'reut2' index.
# Inserted document 350 into the 'reut2' index.
# Inserted document 351 into the 'reut2' index.
# Inserted document 352 into the 'reut2' index.
# Inserted document 353 into the 'reut2' index.
# Inserted document 354 into the 'reut2' index.
# Inserted document 355 into the 'reut2' index.
# Inserted document 356 into the 'reut2' index.
# Inserted document 357 into the 'reut2' index.
# Inserted document 358 into the 'reut2' index.
# Inserted document 359 into the 'reut2' index.
# Inserted document 360 into the 'reut2' index.
# Inserted document 361 into the 'reut2' index.
# Inserted document 362 into the 'reut2' index.
# Inserted document 363 into the 'reut2' index.
# Inserted document 364 into the 'reut2' index.
# Inserted document 365 into the 'reut2' index.
# Inserted document 366 into the 'reut2' index.
# Inserted document 367 into the 'reut2' index.
# Inserted document 368 into the 'reut2' index.
# Inserted document 369 into the 'reut2' index.
# Inserted document 370 into the 'reut2' index.
# Inserted document 371 into the 'reut2' index.
# Inserted document 372 into the 'reut2' index.
# Inserted document 373 into the 'reut2' index.
# Inserted document 374 into the 'reut2' index.
# Inserted document 375 into the 'reut2' index.
# Inserted document 376 into the 'reut2' index.
# Inserted document 377 into the 'reut2' index.
# Inserted document 378 into the 'reut2' index.
# Inserted document 379 into the 'reut2' index.
# Inserted document 380 into the 'reut2' index.
# Inserted document 381 into the 'reut2' index.
# Inserted document 382 into the 'reut2' index.
# Inserted document 383 into the 'reut2' index.
# Inserted document 384 into the 'reut2' index.
# Inserted document 385 into the 'reut2' index.
# Inserted document 386 into the 'reut2' index.
# Inserted document 387 into the 'reut2' index.
# Inserted document 388 into the 'reut2' index.
# Inserted document 389 into the 'reut2' index.
# Inserted document 390 into the 'reut2' index.
# Inserted document 391 into the 'reut2' index.
# Inserted document 392 into the 'reut2' index.
# Inserted document 393 into the 'reut2' index.
# Inserted document 394 into the 'reut2' index.
# Inserted document 395 into the 'reut2' index.
# Inserted document 396 into the 'reut2' index.
# Inserted document 397 into the 'reut2' index.
# Inserted document 398 into the 'reut2' index.
# Inserted document 399 into the 'reut2' index.
# Inserted document 400 into the 'reut2' index.
# Inserted document 401 into the 'reut2' index.
# Inserted document 402 into the 'reut2' index.
# Inserted document 403 into the 'reut2' index.
# Inserted document 404 into the 'reut2' index.
# Inserted document 405 into the 'reut2' index.
# Inserted document 406 into the 'reut2' index.
# Inserted document 407 into the 'reut2' index.
# Inserted document 408 into the 'reut2' index.
# Inserted document 409 into the 'reut2' index.
# Inserted document 410 into the 'reut2' index.
# Inserted document 411 into the 'reut2' index.
# Inserted document 412 into the 'reut2' index.
# Inserted document 413 into the 'reut2' index.
# Inserted document 414 into the 'reut2' index.
# Inserted document 415 into the 'reut2' index.
# Inserted document 416 into the 'reut2' index.
# Inserted document 417 into the 'reut2' index.
# Inserted document 418 into the 'reut2' index.
# Inserted document 419 into the 'reut2' index.
# Inserted document 420 into the 'reut2' index.
# Inserted document 421 into the 'reut2' index.
# Inserted document 422 into the 'reut2' index.
# Inserted document 423 into the 'reut2' index.
# Inserted document 424 into the 'reut2' index.
# Inserted document 425 into the 'reut2' index.
# Inserted document 426 into the 'reut2' index.
# Inserted document 427 into the 'reut2' index.
# Inserted document 428 into the 'reut2' index.
# Inserted document 429 into the 'reut2' index.
# Inserted document 430 into the 'reut2' index.
# Inserted document 431 into the 'reut2' index.
# Inserted document 432 into the 'reut2' index.
# Inserted document 433 into the 'reut2' index.
# Inserted document 434 into the 'reut2' index.
# Inserted document 435 into the 'reut2' index.
# Inserted document 436 into the 'reut2' index.
# Inserted document 437 into the 'reut2' index.
# Inserted document 438 into the 'reut2' index.
# Inserted document 439 into the 'reut2' index.
# Inserted document 440 into the 'reut2' index.
# Inserted document 441 into the 'reut2' index.
# Inserted document 442 into the 'reut2' index.
# Inserted document 443 into the 'reut2' index.
# Inserted document 444 into the 'reut2' index.
# Inserted document 445 into the 'reut2' index.
# Inserted document 446 into the 'reut2' index.
# Inserted document 447 into the 'reut2' index.
# Inserted document 448 into the 'reut2' index.
# Inserted document 449 into the 'reut2' index.
# Inserted document 450 into the 'reut2' index.
# Inserted document 451 into the 'reut2' index.
# Inserted document 452 into the 'reut2' index.
# Inserted document 453 into the 'reut2' index.
# Inserted document 454 into the 'reut2' index.
# Inserted document 455 into the 'reut2' index.
# Inserted document 456 into the 'reut2' index.
# Inserted document 457 into the 'reut2' index.
# Inserted document 458 into the 'reut2' index.
# Inserted document 459 into the 'reut2' index.
# Inserted document 460 into the 'reut2' index.
# Inserted document 461 into the 'reut2' index.
# Inserted document 462 into the 'reut2' index.
# Inserted document 463 into the 'reut2' index.
# Inserted document 464 into the 'reut2' index.
# Inserted document 465 into the 'reut2' index.
# Inserted document 466 into the 'reut2' index.
# Inserted document 467 into the 'reut2' index.
# Inserted document 468 into the 'reut2' index.
# Inserted document 469 into the 'reut2' index.
# Inserted document 470 into the 'reut2' index.
# Inserted document 471 into the 'reut2' index.
# Inserted document 472 into the 'reut2' index.
# Inserted document 473 into the 'reut2' index.
# Inserted document 474 into the 'reut2' index.
# Inserted document 475 into the 'reut2' index.
# Inserted document 476 into the 'reut2' index.
# Inserted document 477 into the 'reut2' index.
# Inserted document 478 into the 'reut2' index.
# Inserted document 479 into the 'reut2' index.
# Inserted document 480 into the 'reut2' index.
# Inserted document 481 into the 'reut2' index.
# Inserted document 482 into the 'reut2' index.
# Inserted document 483 into the 'reut2' index.
# Inserted document 484 into the 'reut2' index.
# Inserted document 485 into the 'reut2' index.
# Inserted document 486 into the 'reut2' index.
# Inserted document 487 into the 'reut2' index.
# Inserted document 488 into the 'reut2' index.
# Inserted document 489 into the 'reut2' index.
# Inserted document 490 into the 'reut2' index.
# Inserted document 491 into the 'reut2' index.
# Inserted document 492 into the 'reut2' index.
# Inserted document 493 into the 'reut2' index.
# Inserted document 494 into the 'reut2' index.
# Inserted document 495 into the 'reut2' index.
# Inserted document 496 into the 'reut2' index.
# Inserted document 497 into the 'reut2' index.
# Inserted document 498 into the 'reut2' index.
# Inserted document 499 into the 'reut2' index.
# Inserted document 500 into the 'reut2' index.
# Inserted document 501 into the 'reut2' index.
# Inserted document 502 into the 'reut2' index.
# Inserted document 503 into the 'reut2' index.
# Inserted document 504 into the 'reut2' index.
# Inserted document 505 into the 'reut2' index.
# Inserted document 506 into the 'reut2' index.
# Inserted document 507 into the 'reut2' index.
# Inserted document 508 into the 'reut2' index.
# Inserted document 509 into the 'reut2' index.
# Inserted document 510 into the 'reut2' index.
# Inserted document 511 into the 'reut2' index.
# Inserted document 512 into the 'reut2' index.
# Inserted document 513 into the 'reut2' index.
# Inserted document 514 into the 'reut2' index.
# Inserted document 515 into the 'reut2' index.
# Inserted document 516 into the 'reut2' index.
# Inserted document 517 into the 'reut2' index.
# Inserted document 518 into the 'reut2' index.
# Inserted document 519 into the 'reut2' index.
# Inserted document 520 into the 'reut2' index.
# Inserted document 521 into the 'reut2' index.
# Inserted document 522 into the 'reut2' index.
# Inserted document 523 into the 'reut2' index.
# Inserted document 524 into the 'reut2' index.
# Inserted document 525 into the 'reut2' index.
# Inserted document 526 into the 'reut2' index.
# Inserted document 527 into the 'reut2' index.
# Inserted document 528 into the 'reut2' index.
# Inserted document 529 into the 'reut2' index.
# Inserted document 530 into the 'reut2' index.
# Inserted document 531 into the 'reut2' index.
# Inserted document 532 into the 'reut2' index.
# Inserted document 533 into the 'reut2' index.
# Inserted document 534 into the 'reut2' index.
# Inserted document 535 into the 'reut2' index.
# Inserted document 536 into the 'reut2' index.
# Inserted document 537 into the 'reut2' index.
# Inserted document 538 into the 'reut2' index.
# Inserted document 539 into the 'reut2' index.
# Inserted document 540 into the 'reut2' index.
# Inserted document 541 into the 'reut2' index.
# Inserted document 542 into the 'reut2' index.
# Inserted document 543 into the 'reut2' index.
# Inserted document 544 into the 'reut2' index.
# Inserted document 545 into the 'reut2' index.
# Inserted document 546 into the 'reut2' index.
# Inserted document 547 into the 'reut2' index.
# Inserted document 548 into the 'reut2' index.
# Inserted document 549 into the 'reut2' index.
# Inserted document 550 into the 'reut2' index.
# Inserted document 551 into the 'reut2' index.
# Inserted document 552 into the 'reut2' index.
# Inserted document 553 into the 'reut2' index.
# Inserted document 554 into the 'reut2' index.
# Inserted document 555 into the 'reut2' index.
# Inserted document 556 into the 'reut2' index.
# Inserted document 557 into the 'reut2' index.
# Inserted document 558 into the 'reut2' index.
# Inserted document 559 into the 'reut2' index.
# Inserted document 560 into the 'reut2' index.
# Inserted document 561 into the 'reut2' index.
# Inserted document 562 into the 'reut2' index.
# Inserted document 563 into the 'reut2' index.
# Inserted document 564 into the 'reut2' index.
# Inserted document 565 into the 'reut2' index.
# Inserted document 566 into the 'reut2' index.
# Inserted document 567 into the 'reut2' index.
# Inserted document 568 into the 'reut2' index.
# Inserted document 569 into the 'reut2' index.
# Inserted document 570 into the 'reut2' index.
# Inserted document 571 into the 'reut2' index.
# Inserted document 572 into the 'reut2' index.
# Inserted document 573 into the 'reut2' index.
# Inserted document 574 into the 'reut2' index.
# Inserted document 575 into the 'reut2' index.
# Inserted document 576 into the 'reut2' index.
# Inserted document 577 into the 'reut2' index.
# Inserted document 578 into the 'reut2' index.
# Inserted document 579 into the 'reut2' index.
# Inserted document 580 into the 'reut2' index.
# Inserted document 581 into the 'reut2' index.
# Inserted document 582 into the 'reut2' index.
# Inserted document 583 into the 'reut2' index.
# Inserted document 584 into the 'reut2' index.
# Inserted document 585 into the 'reut2' index.
# Inserted document 586 into the 'reut2' index.
# Inserted document 587 into the 'reut2' index.
# Inserted document 588 into the 'reut2' index.
# Inserted document 589 into the 'reut2' index.
# Inserted document 590 into the 'reut2' index.
# Inserted document 591 into the 'reut2' index.
# Inserted document 592 into the 'reut2' index.
# Inserted document 593 into the 'reut2' index.
# Inserted document 594 into the 'reut2' index.
# Inserted document 595 into the 'reut2' index.
# Inserted document 596 into the 'reut2' index.
# Inserted document 597 into the 'reut2' index.
# Inserted document 598 into the 'reut2' index.
# Inserted document 599 into the 'reut2' index.
# Inserted document 600 into the 'reut2' index.
# Inserted document 601 into the 'reut2' index.
# Inserted document 602 into the 'reut2' index.
# Inserted document 603 into the 'reut2' index.
# Inserted document 604 into the 'reut2' index.
# Inserted document 605 into the 'reut2' index.
# Inserted document 606 into the 'reut2' index.
# Inserted document 607 into the 'reut2' index.
# Inserted document 608 into the 'reut2' index.
# Inserted document 609 into the 'reut2' index.
# Inserted document 610 into the 'reut2' index.
# Inserted document 611 into the 'reut2' index.
# Inserted document 612 into the 'reut2' index.
# Inserted document 613 into the 'reut2' index.
# Inserted document 614 into the 'reut2' index.
# Inserted document 615 into the 'reut2' index.
# Inserted document 616 into the 'reut2' index.
# Inserted document 617 into the 'reut2' index.
# Inserted document 618 into the 'reut2' index.
# Inserted document 619 into the 'reut2' index.
# Inserted document 620 into the 'reut2' index.
# Inserted document 621 into the 'reut2' index.
# Inserted document 622 into the 'reut2' index.
# Inserted document 623 into the 'reut2' index.
# Inserted document 624 into the 'reut2' index.
# Inserted document 625 into the 'reut2' index.
# Inserted document 626 into the 'reut2' index.
# Inserted document 627 into the 'reut2' index.
# Inserted document 628 into the 'reut2' index.
# Inserted document 629 into the 'reut2' index.
# Inserted document 630 into the 'reut2' index.
# Inserted document 631 into the 'reut2' index.
# Inserted document 632 into the 'reut2' index.
# Inserted document 633 into the 'reut2' index.
# Inserted document 634 into the 'reut2' index.
# Inserted document 635 into the 'reut2' index.
# Inserted document 636 into the 'reut2' index.
# Inserted document 637 into the 'reut2' index.
# Inserted document 638 into the 'reut2' index.
# Inserted document 639 into the 'reut2' index.
# Inserted document 640 into the 'reut2' index.
# Inserted document 641 into the 'reut2' index.
# Inserted document 642 into the 'reut2' index.
# Inserted document 643 into the 'reut2' index.
# Inserted document 644 into the 'reut2' index.
# Inserted document 645 into the 'reut2' index.
# Inserted document 646 into the 'reut2' index.
# Inserted document 647 into the 'reut2' index.
# Inserted document 648 into the 'reut2' index.
# Inserted document 649 into the 'reut2' index.
# Inserted document 650 into the 'reut2' index.
# Inserted document 651 into the 'reut2' index.
# Inserted document 652 into the 'reut2' index.
# Inserted document 653 into the 'reut2' index.
# Inserted document 654 into the 'reut2' index.
# Inserted document 655 into the 'reut2' index.
# Inserted document 656 into the 'reut2' index.
# Inserted document 657 into the 'reut2' index.
# Inserted document 658 into the 'reut2' index.
# Inserted document 659 into the 'reut2' index.
# Inserted document 660 into the 'reut2' index.
# Inserted document 661 into the 'reut2' index.
# Inserted document 662 into the 'reut2' index.
# Inserted document 663 into the 'reut2' index.
# Inserted document 664 into the 'reut2' index.
# Inserted document 665 into the 'reut2' index.
# Inserted document 666 into the 'reut2' index.
# Inserted document 667 into the 'reut2' index.
# Inserted document 668 into the 'reut2' index.
# Inserted document 669 into the 'reut2' index.
# Inserted document 670 into the 'reut2' index.
# Inserted document 671 into the 'reut2' index.
# Inserted document 672 into the 'reut2' index.
# Inserted document 673 into the 'reut2' index.
# Inserted document 674 into the 'reut2' index.
# Inserted document 675 into the 'reut2' index.
# Inserted document 676 into the 'reut2' index.
# Inserted document 677 into the 'reut2' index.
# Inserted document 678 into the 'reut2' index.
# Inserted document 679 into the 'reut2' index.
# Inserted document 680 into the 'reut2' index.
# Inserted document 681 into the 'reut2' index.
# Inserted document 682 into the 'reut2' index.
# Inserted document 683 into the 'reut2' index.
# Inserted document 684 into the 'reut2' index.
# Inserted document 685 into the 'reut2' index.
# Inserted document 686 into the 'reut2' index.
# Inserted document 687 into the 'reut2' index.
# Inserted document 688 into the 'reut2' index.
# Inserted document 689 into the 'reut2' index.
# Inserted document 690 into the 'reut2' index.
# Inserted document 691 into the 'reut2' index.
# Inserted document 692 into the 'reut2' index.
# Inserted document 693 into the 'reut2' index.
# Inserted document 694 into the 'reut2' index.
# Inserted document 695 into the 'reut2' index.
# Inserted document 696 into the 'reut2' index.
# Inserted document 697 into the 'reut2' index.
# Inserted document 698 into the 'reut2' index.
# Inserted document 699 into the 'reut2' index.
# Inserted document 700 into the 'reut2' index.
# Inserted document 701 into the 'reut2' index.
# Inserted document 702 into the 'reut2' index.
# Inserted document 703 into the 'reut2' index.
# Inserted document 704 into the 'reut2' index.
# Inserted document 705 into the 'reut2' index.
# Inserted document 706 into the 'reut2' index.
# Inserted document 707 into the 'reut2' index.
# Inserted document 708 into the 'reut2' index.
# Inserted document 709 into the 'reut2' index.
# Inserted document 710 into the 'reut2' index.
# Inserted document 711 into the 'reut2' index.
# Inserted document 712 into the 'reut2' index.
# Inserted document 713 into the 'reut2' index.
# Inserted document 714 into the 'reut2' index.
# Inserted document 715 into the 'reut2' index.
# Inserted document 716 into the 'reut2' index.
# Inserted document 717 into the 'reut2' index.
# Inserted document 718 into the 'reut2' index.
# Inserted document 719 into the 'reut2' index.
# Inserted document 720 into the 'reut2' index.
# Inserted document 721 into the 'reut2' index.
# Inserted document 722 into the 'reut2' index.
# Inserted document 723 into the 'reut2' index.
# Inserted document 724 into the 'reut2' index.
# Inserted document 725 into the 'reut2' index.
# Inserted document 726 into the 'reut2' index.
# Inserted document 727 into the 'reut2' index.
# Inserted document 728 into the 'reut2' index.
# Inserted document 729 into the 'reut2' index.
# Inserted document 730 into the 'reut2' index.
# Inserted document 731 into the 'reut2' index.
# Inserted document 732 into the 'reut2' index.
# Inserted document 733 into the 'reut2' index.
# Inserted document 734 into the 'reut2' index.
# Inserted document 735 into the 'reut2' index.
# Inserted document 736 into the 'reut2' index.
# Inserted document 737 into the 'reut2' index.
# Inserted document 738 into the 'reut2' index.
# Inserted document 739 into the 'reut2' index.
# Inserted document 740 into the 'reut2' index.
# Inserted document 741 into the 'reut2' index.
# Inserted document 742 into the 'reut2' index.
# Inserted document 743 into the 'reut2' index.
# Inserted document 744 into the 'reut2' index.
# Inserted document 745 into the 'reut2' index.
# Inserted document 746 into the 'reut2' index.
# Inserted document 747 into the 'reut2' index.
# Inserted document 748 into the 'reut2' index.
# Inserted document 749 into the 'reut2' index.
# Inserted document 750 into the 'reut2' index.
# Inserted document 751 into the 'reut2' index.
# Inserted document 752 into the 'reut2' index.
# Inserted document 753 into the 'reut2' index.
# Inserted document 754 into the 'reut2' index.
# Inserted document 755 into the 'reut2' index.
# Inserted document 756 into the 'reut2' index.
# Inserted document 757 into the 'reut2' index.
# Inserted document 758 into the 'reut2' index.
# Inserted document 759 into the 'reut2' index.
# Inserted document 760 into the 'reut2' index.
# Inserted document 761 into the 'reut2' index.
# Inserted document 762 into the 'reut2' index.
# Inserted document 763 into the 'reut2' index.
# Inserted document 764 into the 'reut2' index.
# Inserted document 765 into the 'reut2' index.
# Inserted document 766 into the 'reut2' index.
# Inserted document 767 into the 'reut2' index.
# Inserted document 768 into the 'reut2' index.
# Inserted document 769 into the 'reut2' index.
# Inserted document 770 into the 'reut2' index.
# Inserted document 771 into the 'reut2' index.
# Inserted document 772 into the 'reut2' index.
# Inserted document 773 into the 'reut2' index.
# Inserted document 774 into the 'reut2' index.
# Inserted document 775 into the 'reut2' index.
# Inserted document 776 into the 'reut2' index.
# Inserted document 777 into the 'reut2' index.
# Inserted document 778 into the 'reut2' index.
# Inserted document 779 into the 'reut2' index.
# Inserted document 780 into the 'reut2' index.
# Inserted document 781 into the 'reut2' index.
# Inserted document 782 into the 'reut2' index.
# Inserted document 783 into the 'reut2' index.
# Inserted document 784 into the 'reut2' index.
# Inserted document 785 into the 'reut2' index.
# Inserted document 786 into the 'reut2' index.
# Inserted document 787 into the 'reut2' index.
# Inserted document 788 into the 'reut2' index.
# Inserted document 789 into the 'reut2' index.
# Inserted document 790 into the 'reut2' index.
# Inserted document 791 into the 'reut2' index.
# Inserted document 792 into the 'reut2' index.
# Inserted document 793 into the 'reut2' index.
# Inserted document 794 into the 'reut2' index.
# Inserted document 795 into the 'reut2' index.
# Inserted document 796 into the 'reut2' index.
# Inserted document 797 into the 'reut2' index.
# Inserted document 798 into the 'reut2' index.
# Inserted document 799 into the 'reut2' index.
# Inserted document 800 into the 'reut2' index.
# Inserted document 801 into the 'reut2' index.
# Inserted document 802 into the 'reut2' index.
# Inserted document 803 into the 'reut2' index.
# Inserted document 804 into the 'reut2' index.
# Inserted document 805 into the 'reut2' index.
# Inserted document 806 into the 'reut2' index.
# Inserted document 807 into the 'reut2' index.
# Inserted document 808 into the 'reut2' index.
# Inserted document 809 into the 'reut2' index.
# Inserted document 810 into the 'reut2' index.
# Inserted document 811 into the 'reut2' index.
# Inserted document 812 into the 'reut2' index.
# Inserted document 813 into the 'reut2' index.
# Inserted document 814 into the 'reut2' index.
# Inserted document 815 into the 'reut2' index.
# Inserted document 816 into the 'reut2' index.
# Inserted document 817 into the 'reut2' index.
# Inserted document 818 into the 'reut2' index.
# Inserted document 819 into the 'reut2' index.
# Inserted document 820 into the 'reut2' index.
# Inserted document 821 into the 'reut2' index.
# Inserted document 822 into the 'reut2' index.
# Inserted document 823 into the 'reut2' index.
# Inserted document 824 into the 'reut2' index.
# Inserted document 825 into the 'reut2' index.
# Inserted document 826 into the 'reut2' index.
# Inserted document 827 into the 'reut2' index.
# Inserted document 828 into the 'reut2' index.
# Inserted document 829 into the 'reut2' index.
# Inserted document 830 into the 'reut2' index.
# Inserted document 831 into the 'reut2' index.
# Inserted document 832 into the 'reut2' index.
# Inserted document 833 into the 'reut2' index.
# Inserted document 834 into the 'reut2' index.
# Inserted document 835 into the 'reut2' index.
# Inserted document 836 into the 'reut2' index.
# Inserted document 837 into the 'reut2' index.
# Inserted document 838 into the 'reut2' index.
# Inserted document 839 into the 'reut2' index.
# Inserted document 840 into the 'reut2' index.
# Inserted document 841 into the 'reut2' index.
# Inserted document 842 into the 'reut2' index.
# Inserted document 843 into the 'reut2' index.
# Inserted document 844 into the 'reut2' index.
# Inserted document 845 into the 'reut2' index.
# Inserted document 846 into the 'reut2' index.
# Inserted document 847 into the 'reut2' index.
# Inserted document 848 into the 'reut2' index.
# Inserted document 849 into the 'reut2' index.
# Inserted document 850 into the 'reut2' index.
# Inserted document 851 into the 'reut2' index.
# Inserted document 852 into the 'reut2' index.
# Inserted document 853 into the 'reut2' index.
# Inserted document 854 into the 'reut2' index.
# Inserted document 855 into the 'reut2' index.
# Inserted document 856 into the 'reut2' index.
# Inserted document 857 into the 'reut2' index.
# Inserted document 858 into the 'reut2' index.
# Inserted document 859 into the 'reut2' index.
# Inserted document 860 into the 'reut2' index.
# Inserted document 861 into the 'reut2' index.
# Inserted document 862 into the 'reut2' index.
# Inserted document 863 into the 'reut2' index.
# Inserted document 864 into the 'reut2' index.
# Inserted document 865 into the 'reut2' index.
# Inserted document 866 into the 'reut2' index.
# Inserted document 867 into the 'reut2' index.
# Inserted document 868 into the 'reut2' index.
# Inserted document 869 into the 'reut2' index.
# Inserted document 870 into the 'reut2' index.
# Inserted document 871 into the 'reut2' index.
# Inserted document 872 into the 'reut2' index.
# Inserted document 873 into the 'reut2' index.
# Inserted document 874 into the 'reut2' index.
# Inserted document 875 into the 'reut2' index.
# Inserted document 876 into the 'reut2' index.
# Inserted document 877 into the 'reut2' index.
# Inserted document 878 into the 'reut2' index.
# Inserted document 879 into the 'reut2' index.
# Inserted document 880 into the 'reut2' index.
# Inserted document 881 into the 'reut2' index.
# Inserted document 882 into the 'reut2' index.
# Inserted document 883 into the 'reut2' index.
# Inserted document 884 into the 'reut2' index.
# Inserted document 885 into the 'reut2' index.
# Inserted document 886 into the 'reut2' index.
# Inserted document 887 into the 'reut2' index.
# Inserted document 888 into the 'reut2' index.
# Inserted document 889 into the 'reut2' index.
# Inserted document 890 into the 'reut2' index.
# Inserted document 891 into the 'reut2' index.
# Inserted document 892 into the 'reut2' index.
# Inserted document 893 into the 'reut2' index.
# Inserted document 894 into the 'reut2' index.
# Inserted document 895 into the 'reut2' index.
# Inserted document 896 into the 'reut2' index.
# Inserted document 897 into the 'reut2' index.
# Inserted document 898 into the 'reut2' index.
# Inserted document 899 into the 'reut2' index.
# Inserted document 900 into the 'reut2' index.
# Inserted document 901 into the 'reut2' index.
# Inserted document 902 into the 'reut2' index.
# Inserted document 903 into the 'reut2' index.
# Inserted document 904 into the 'reut2' index.
# Inserted document 905 into the 'reut2' index.
# Inserted document 906 into the 'reut2' index.
# Inserted document 907 into the 'reut2' index.
# Inserted document 908 into the 'reut2' index.
# Inserted document 909 into the 'reut2' index.
# Inserted document 910 into the 'reut2' index.
# Inserted document 911 into the 'reut2' index.
# Inserted document 912 into the 'reut2' index.
# Inserted document 913 into the 'reut2' index.
# Inserted document 914 into the 'reut2' index.
# Inserted document 915 into the 'reut2' index.
# Inserted document 916 into the 'reut2' index.
# Inserted document 917 into the 'reut2' index.
# Inserted document 918 into the 'reut2' index.
# Inserted document 919 into the 'reut2' index.
# Inserted document 920 into the 'reut2' index.
# Inserted document 921 into the 'reut2' index.
# Inserted document 922 into the 'reut2' index.
# Inserted document 923 into the 'reut2' index.
# Inserted document 924 into the 'reut2' index.
# Inserted document 925 into the 'reut2' index.
# Inserted document 926 into the 'reut2' index.
# Inserted document 927 into the 'reut2' index.
# Inserted document 928 into the 'reut2' index.
# Inserted document 929 into the 'reut2' index.
# Inserted document 930 into the 'reut2' index.
# Inserted document 931 into the 'reut2' index.
# Inserted document 932 into the 'reut2' index.
# Inserted document 933 into the 'reut2' index.
# Inserted document 934 into the 'reut2' index.
# Inserted document 935 into the 'reut2' index.
# Inserted document 936 into the 'reut2' index.
# Inserted document 937 into the 'reut2' index.
# Inserted document 938 into the 'reut2' index.
# Inserted document 939 into the 'reut2' index.
# Inserted document 940 into the 'reut2' index.
# Inserted document 941 into the 'reut2' index.
# Inserted document 942 into the 'reut2' index.
# Inserted document 943 into the 'reut2' index.
# Inserted document 944 into the 'reut2' index.
# Inserted document 945 into the 'reut2' index.
# Inserted document 946 into the 'reut2' index.
# Inserted document 947 into the 'reut2' index.
# Inserted document 948 into the 'reut2' index.
# Inserted document 949 into the 'reut2' index.
# Inserted document 950 into the 'reut2' index.
# Inserted document 951 into the 'reut2' index.
# Inserted document 952 into the 'reut2' index.
# Inserted document 953 into the 'reut2' index.
# Inserted document 954 into the 'reut2' index.
# Inserted document 955 into the 'reut2' index.
# Inserted document 956 into the 'reut2' index.
# Inserted document 957 into the 'reut2' index.
# Inserted document 958 into the 'reut2' index.
# Inserted document 959 into the 'reut2' index.
# Inserted document 960 into the 'reut2' index.
# Inserted document 961 into the 'reut2' index.
# Inserted document 962 into the 'reut2' index.
# Inserted document 963 into the 'reut2' index.
# Inserted document 964 into the 'reut2' index.
# Inserted document 965 into the 'reut2' index.
# Inserted document 966 into the 'reut2' index.
# Inserted document 967 into the 'reut2' index.
# Inserted document 968 into the 'reut2' index.
# Inserted document 969 into the 'reut2' index.
# Inserted document 970 into the 'reut2' index.
# Inserted document 971 into the 'reut2' index.
# Inserted document 972 into the 'reut2' index.
# Inserted document 973 into the 'reut2' index.
# Inserted document 974 into the 'reut2' index.
# Inserted document 975 into the 'reut2' index.
# Inserted document 976 into the 'reut2' index.
# Inserted document 977 into the 'reut2' index.
# Inserted document 978 into the 'reut2' index.
# Inserted document 979 into the 'reut2' index.
# Inserted document 980 into the 'reut2' index.
# Inserted document 981 into the 'reut2' index.
# Inserted document 982 into the 'reut2' index.
# Inserted document 983 into the 'reut2' index.
# Inserted document 984 into the 'reut2' index.
# Inserted document 985 into the 'reut2' index.
# Inserted document 986 into the 'reut2' index.
# Inserted document 987 into the 'reut2' index.
# Inserted document 988 into the 'reut2' index.
# Inserted document 989 into the 'reut2' index.
# Inserted document 990 into the 'reut2' index.
# Inserted document 991 into the 'reut2' index.
# Inserted document 992 into the 'reut2' index.
# Inserted document 993 into the 'reut2' index.
# Inserted document 994 into the 'reut2' index.
# Inserted document 995 into the 'reut2' index.
# Inserted document 996 into the 'reut2' index.
# Inserted document 997 into the 'reut2' index.
# Inserted document 998 into the 'reut2' index.
# Inserted document 999 into the 'reut2' index.
# Inserted document 1000 into the 'reut2' index.
# Inserted document 1001 into the 'reut2' index.
# Inserted document 1002 into the 'reut2' index.
# Inserted document 1003 into the 'reut2' index.
# Inserted document 1004 into the 'reut2' index.
# Inserted document 1005 into the 'reut2' index.
# Inserted document 1006 into the 'reut2' index.
# Inserted document 1007 into the 'reut2' index.
# Inserted document 1008 into the 'reut2' index.
# Inserted document 1009 into the 'reut2' index.
# Inserted document 1010 into the 'reut2' index.
# Inserted document 1011 into the 'reut2' index.
# Inserted document 1012 into the 'reut2' index.
# Inserted document 1013 into the 'reut2' index.
# Inserted document 1014 into the 'reut2' index.
# Inserted document 1015 into the 'reut2' index.
# Inserted document 1016 into the 'reut2' index.
# Inserted document 1017 into the 'reut2' index.
# Inserted document 1018 into the 'reut2' index.
# Inserted document 1019 into the 'reut2' index.
# Inserted document 1020 into the 'reut2' index.
# Inserted document 1021 into the 'reut2' index.
# Inserted document 1022 into the 'reut2' index.
# Inserted document 1023 into the 'reut2' index.
# Inserted document 1024 into the 'reut2' index.
# Inserted document 1025 into the 'reut2' index.
# Inserted document 1026 into the 'reut2' index.
# Inserted document 1027 into the 'reut2' index.
# Inserted document 1028 into the 'reut2' index.
# Inserted document 1029 into the 'reut2' index.
# Inserted document 1030 into the 'reut2' index.
# Inserted document 1031 into the 'reut2' index.
# Inserted document 1032 into the 'reut2' index.
# Inserted document 1033 into the 'reut2' index.
# Inserted document 1034 into the 'reut2' index.
# Inserted document 1035 into the 'reut2' index.
# Inserted document 1036 into the 'reut2' index.
# Inserted document 1037 into the 'reut2' index.
# Inserted document 1038 into the 'reut2' index.
# Inserted document 1039 into the 'reut2' index.
# Inserted document 1040 into the 'reut2' index.
# Inserted document 1041 into the 'reut2' index.
# Inserted document 1042 into the 'reut2' index.
# Inserted document 1043 into the 'reut2' index.
# Inserted document 1044 into the 'reut2' index.
# ...
# Inserted document 9050 into the 'reut2' index.
# Inserted document 9051 into the 'reut2' index.
# Inserted document 9052 into the 'reut2' index.
# Inserted document 9053 into the 'reut2' index.
# Inserted document 9054 into the 'reut2' index.
# Inserted document 9055 into the 'reut2' index.
# Inserted document 9056 into the 'reut2' index.
# Inserted document 9057 into the 'reut2' index.
# Inserted document 9058 into the 'reut2' index.
# Inserted document 9059 into the 'reut2' index.
# Inserted document 9060 into the 'reut2' index.
# Inserted document 9061 into the 'reut2' index.
# Inserted document 9062 into the 'reut2' index.
# Inserted document 9063 into the 'reut2' index.
# Inserted document 9064 into the 'reut2' index.
# Inserted document 9065 into the 'reut2' index.
# Inserted document 9066 into the 'reut2' index.
# Inserted document 9067 into the 'reut2' index.
# Inserted document 9068 into the 'reut2' index.
# Inserted document 9069 into the 'reut2' index.
# Inserted document 9070 into the 'reut2' index.
# Inserted document 9071 into the 'reut2' index.
# Inserted document 9072 into the 'reut2' index.
# Inserted document 9073 into the 'reut2' index.
# Inserted document 9074 into the 'reut2' index.
# Inserted document 9075 into the 'reut2' index.
# Inserted document 9076 into the 'reut2' index.
# Inserted document 9077 into the 'reut2' index.
# Inserted document 9078 into the 'reut2' index.
# Inserted document 9079 into the 'reut2' index.
# Inserted document 9080 into the 'reut2' index.
# Inserted document 9081 into the 'reut2' index.
# Inserted document 9082 into the 'reut2' index.
# Inserted document 9083 into the 'reut2' index.
# Inserted document 9084 into the 'reut2' index.
# Inserted document 9085 into the 'reut2' index.
# Inserted document 9086 into the 'reut2' index.
# Inserted document 9087 into the 'reut2' index.
# Inserted document 9088 into the 'reut2' index.
# Inserted document 9089 into the 'reut2' index.
# Inserted document 9090 into the 'reut2' index.
# Inserted document 9091 into the 'reut2' index.
# Inserted document 9092 into the 'reut2' index.
# Inserted document 9093 into the 'reut2' index.
# Inserted document 9094 into the 'reut2' index.
# Inserted document 9095 into the 'reut2' index.
# Inserted document 9096 into the 'reut2' index.
# Inserted document 9097 into the 'reut2' index.
# Inserted document 9098 into the 'reut2' index.
# Inserted document 9099 into the 'reut2' index.
# Inserted document 9100 into the 'reut2' index.
# Inserted document 9101 into the 'reut2' index.
# Inserted document 9102 into the 'reut2' index.
# Inserted document 9103 into the 'reut2' index.
# Inserted document 9104 into the 'reut2' index.
# Inserted document 9105 into the 'reut2' index.
# Inserted document 9106 into the 'reut2' index.
# Inserted document 9107 into the 'reut2' index.
# Inserted document 9108 into the 'reut2' index.
# Inserted document 9109 into the 'reut2' index.
# Inserted document 9110 into the 'reut2' index.
# Inserted document 9111 into the 'reut2' index.
# Inserted document 9112 into the 'reut2' index.
# Inserted document 9113 into the 'reut2' index.
# Inserted document 9114 into the 'reut2' index.
# Inserted document 9115 into the 'reut2' index.
# Inserted document 9116 into the 'reut2' index.
# Inserted document 9117 into the 'reut2' index.
# Inserted document 9118 into the 'reut2' index.
# Inserted document 9119 into the 'reut2' index.
# Inserted document 9120 into the 'reut2' index.
# Inserted document 9121 into the 'reut2' index.
# Inserted document 9122 into the 'reut2' index.
# Inserted document 9123 into the 'reut2' index.
# Inserted document 9124 into the 'reut2' index.
# Inserted document 9125 into the 'reut2' index.
# Inserted document 9126 into the 'reut2' index.
# Inserted document 9127 into the 'reut2' index.
# Inserted document 9128 into the 'reut2' index.
# Inserted document 9129 into the 'reut2' index.
# Inserted document 9130 into the 'reut2' index.
# Inserted document 9131 into the 'reut2' index.
# Inserted document 9132 into the 'reut2' index.
# Inserted document 9133 into the 'reut2' index.
# Inserted document 9134 into the 'reut2' index.
# Inserted document 9135 into the 'reut2' index.
# Inserted document 9136 into the 'reut2' index.
# Inserted document 9137 into the 'reut2' index.
# Inserted document 9138 into the 'reut2' index.
# Inserted document 9139 into the 'reut2' index.
# Inserted document 9140 into the 'reut2' index.
# Inserted document 9141 into the 'reut2' index.
# Inserted document 9142 into the 'reut2' index.
# Inserted document 9143 into the 'reut2' index.
# Inserted document 9144 into the 'reut2' index.
# Inserted document 9145 into the 'reut2' index.
# Inserted document 9146 into the 'reut2' index.
# Inserted document 9147 into the 'reut2' index.
# Inserted document 9148 into the 'reut2' index.
# Inserted document 9149 into the 'reut2' index.
# Inserted document 9150 into the 'reut2' index.
# Inserted document 9151 into the 'reut2' index.
# Inserted document 9152 into the 'reut2' index.
# Inserted document 9153 into the 'reut2' index.
# Inserted document 9154 into the 'reut2' index.
# Inserted document 9155 into the 'reut2' index.
# Inserted document 9156 into the 'reut2' index.
# Inserted document 9157 into the 'reut2' index.
# Inserted document 9158 into the 'reut2' index.
# Inserted document 9159 into the 'reut2' index.
# Inserted document 9160 into the 'reut2' index.
# Inserted document 9161 into the 'reut2' index.
# Inserted document 9162 into the 'reut2' index.
# Inserted document 9163 into the 'reut2' index.
# Inserted document 9164 into the 'reut2' index.
# Inserted document 9165 into the 'reut2' index.
# Inserted document 9166 into the 'reut2' index.
# Inserted document 9167 into the 'reut2' index.
# Inserted document 9168 into the 'reut2' index.
# Inserted document 9169 into the 'reut2' index.
# Inserted document 9170 into the 'reut2' index.
# Inserted document 9171 into the 'reut2' index.
# Inserted document 9172 into the 'reut2' index.
# Inserted document 9173 into the 'reut2' index.
# Inserted document 9174 into the 'reut2' index.
# Inserted document 9175 into the 'reut2' index.
# Inserted document 9176 into the 'reut2' index.
# Inserted document 9177 into the 'reut2' index.
# Inserted document 9178 into the 'reut2' index.
# Inserted document 9179 into the 'reut2' index.
# Inserted document 9180 into the 'reut2' index.
# Inserted document 9181 into the 'reut2' index.
# Inserted document 9182 into the 'reut2' index.
# Inserted document 9183 into the 'reut2' index.
# Inserted document 9184 into the 'reut2' index.
# Inserted document 9185 into the 'reut2' index.
# Inserted document 9186 into the 'reut2' index.
# Inserted document 9187 into the 'reut2' index.
# Inserted document 9188 into the 'reut2' index.
# Inserted document 9189 into the 'reut2' index.
# Inserted document 9190 into the 'reut2' index.
# Inserted document 9191 into the 'reut2' index.
# Inserted document 9192 into the 'reut2' index.
# Inserted document 9193 into the 'reut2' index.
# Inserted document 9194 into the 'reut2' index.
# Inserted document 9195 into the 'reut2' index.
# Inserted document 9196 into the 'reut2' index.
# Inserted document 9197 into the 'reut2' index.
# Inserted document 9198 into the 'reut2' index.
# Inserted document 9199 into the 'reut2' index.
# Inserted document 9200 into the 'reut2' index.
# Inserted document 9201 into the 'reut2' index.
# Inserted document 9202 into the 'reut2' index.
# Inserted document 9203 into the 'reut2' index.
# Inserted document 9204 into the 'reut2' index.
# Inserted document 9205 into the 'reut2' index.
# Inserted document 9206 into the 'reut2' index.
# Inserted document 9207 into the 'reut2' index.
# Inserted document 9208 into the 'reut2' index.
# Inserted document 9209 into the 'reut2' index.
# Inserted document 9210 into the 'reut2' index.
# Inserted document 9211 into the 'reut2' index.
# Inserted document 9212 into the 'reut2' index.
# Inserted document 9213 into the 'reut2' index.
# Inserted document 9214 into the 'reut2' index.
# Inserted document 9215 into the 'reut2' index.
# Inserted document 9216 into the 'reut2' index.
# Inserted document 9217 into the 'reut2' index.
# Inserted document 9218 into the 'reut2' index.
# Inserted document 9219 into the 'reut2' index.
# Inserted document 9220 into the 'reut2' index.
# Inserted document 9221 into the 'reut2' index.
# Inserted document 9222 into the 'reut2' index.
# Inserted document 9223 into the 'reut2' index.
# Inserted document 9224 into the 'reut2' index.
# Inserted document 9225 into the 'reut2' index.
# Inserted document 9226 into the 'reut2' index.
# Inserted document 9227 into the 'reut2' index.
# Inserted document 9228 into the 'reut2' index.
# Inserted document 9229 into the 'reut2' index.
# Inserted document 9230 into the 'reut2' index.
# Inserted document 9231 into the 'reut2' index.
# Inserted document 9232 into the 'reut2' index.
# Inserted document 9233 into the 'reut2' index.
# Inserted document 9234 into the 'reut2' index.
# Inserted document 9235 into the 'reut2' index.
# Inserted document 9236 into the 'reut2' index.
# Inserted document 9237 into the 'reut2' index.
# Inserted document 9238 into the 'reut2' index.
# Inserted document 9239 into the 'reut2' index.
# Inserted document 9240 into the 'reut2' index.
# Inserted document 9241 into the 'reut2' index.
# Inserted document 9242 into the 'reut2' index.
# Inserted document 9243 into the 'reut2' index.
# Inserted document 9244 into the 'reut2' index.
# Inserted document 9245 into the 'reut2' index.
# Inserted document 9246 into the 'reut2' index.
# Inserted document 9247 into the 'reut2' index.
# Inserted document 9248 into the 'reut2' index.
# Inserted document 9249 into the 'reut2' index.
# Inserted document 9250 into the 'reut2' index.
# Inserted document 9251 into the 'reut2' index.
# Inserted document 9252 into the 'reut2' index.
# Inserted document 9253 into the 'reut2' index.
# Inserted document 9254 into the 'reut2' index.
# Inserted document 9255 into the 'reut2' index.
# Inserted document 9256 into the 'reut2' index.
# Inserted document 9257 into the 'reut2' index.
# Inserted document 9258 into the 'reut2' index.
# Inserted document 9259 into the 'reut2' index.
# Inserted document 9260 into the 'reut2' index.
# Inserted document 9261 into the 'reut2' index.
# Inserted document 9262 into the 'reut2' index.
# Inserted document 9263 into the 'reut2' index.
# Inserted document 9264 into the 'reut2' index.
# Inserted document 9265 into the 'reut2' index.
# Inserted document 9266 into the 'reut2' index.
# Inserted document 9267 into the 'reut2' index.
# Inserted document 9268 into the 'reut2' index.
# Inserted document 9269 into the 'reut2' index.
# Inserted document 9270 into the 'reut2' index.
# Inserted document 9271 into the 'reut2' index.
# Inserted document 9272 into the 'reut2' index.
# Inserted document 9273 into the 'reut2' index.
# Inserted document 9274 into the 'reut2' index.
# Inserted document 9275 into the 'reut2' index.
# Inserted document 9276 into the 'reut2' index.
# Inserted document 9277 into the 'reut2' index.
# Inserted document 9278 into the 'reut2' index.
# Inserted document 9279 into the 'reut2' index.
# Inserted document 9280 into the 'reut2' index.
# Inserted document 9281 into the 'reut2' index.
# Inserted document 9282 into the 'reut2' index.
# Inserted document 9283 into the 'reut2' index.
# Inserted document 9284 into the 'reut2' index.
# Inserted document 9285 into the 'reut2' index.
# Inserted document 9286 into the 'reut2' index.
# Inserted document 9287 into the 'reut2' index.
# Inserted document 9288 into the 'reut2' index.
# Inserted document 9289 into the 'reut2' index.
# Inserted document 9290 into the 'reut2' index.
# Inserted document 9291 into the 'reut2' index.
# Inserted document 9292 into the 'reut2' index.
# Inserted document 9293 into the 'reut2' index.
# Inserted document 9294 into the 'reut2' index.
# Inserted document 9295 into the 'reut2' index.
# Inserted document 9296 into the 'reut2' index.
# Inserted document 9297 into the 'reut2' index.
# Inserted document 9298 into the 'reut2' index.
# Inserted document 9299 into the 'reut2' index.
# Inserted document 9300 into the 'reut2' index.
# Inserted document 9301 into the 'reut2' index.
# Inserted document 9302 into the 'reut2' index.
# Inserted document 9303 into the 'reut2' index.
# Inserted document 9304 into the 'reut2' index.
# Inserted document 9305 into the 'reut2' index.
# Inserted document 9306 into the 'reut2' index.
# Inserted document 9307 into the 'reut2' index.
# Inserted document 9308 into the 'reut2' index.
# Inserted document 9309 into the 'reut2' index.
# Inserted document 9310 into the 'reut2' index.
# Inserted document 9311 into the 'reut2' index.
# Inserted document 9312 into the 'reut2' index.
# Inserted document 9313 into the 'reut2' index.
# Inserted document 9314 into the 'reut2' index.
# Inserted document 9315 into the 'reut2' index.
# Inserted document 9316 into the 'reut2' index.
# Inserted document 9317 into the 'reut2' index.
# Inserted document 9318 into the 'reut2' index.
# Inserted document 9319 into the 'reut2' index.
# Inserted document 9320 into the 'reut2' index.
# Inserted document 9321 into the 'reut2' index.
# Inserted document 9322 into the 'reut2' index.
# Inserted document 9323 into the 'reut2' index.
# Inserted document 9324 into the 'reut2' index.
# Inserted document 9325 into the 'reut2' index.
# Inserted document 9326 into the 'reut2' index.
# Inserted document 9327 into the 'reut2' index.
# Inserted document 9328 into the 'reut2' index.
# Inserted document 9329 into the 'reut2' index.
# Inserted document 9330 into the 'reut2' index.
# Inserted document 9331 into the 'reut2' index.
# Inserted document 9332 into the 'reut2' index.
# Inserted document 9333 into the 'reut2' index.
# Inserted document 9334 into the 'reut2' index.
# Inserted document 9335 into the 'reut2' index.
# Inserted document 9336 into the 'reut2' index.
# Inserted document 9337 into the 'reut2' index.
# Inserted document 9338 into the 'reut2' index.
# Inserted document 9339 into the 'reut2' index.
# Inserted document 9340 into the 'reut2' index.
# Inserted document 9341 into the 'reut2' index.
# Inserted document 9342 into the 'reut2' index.
# Inserted document 9343 into the 'reut2' index.
# Inserted document 9344 into the 'reut2' index.
# Inserted document 9345 into the 'reut2' index.
# Inserted document 9346 into the 'reut2' index.
# Inserted document 9347 into the 'reut2' index.
# Inserted document 9348 into the 'reut2' index.
# Inserted document 9349 into the 'reut2' index.
# Inserted document 9350 into the 'reut2' index.
# Inserted document 9351 into the 'reut2' index.
# Inserted document 9352 into the 'reut2' index.
# Inserted document 9353 into the 'reut2' index.
# Inserted document 9354 into the 'reut2' index.
# Inserted document 9355 into the 'reut2' index.
# Inserted document 9356 into the 'reut2' index.
# Inserted document 9357 into the 'reut2' index.
# Inserted document 9358 into the 'reut2' index.
# Inserted document 9359 into the 'reut2' index.
# Inserted document 9360 into the 'reut2' index.
# Inserted document 9361 into the 'reut2' index.
# Inserted document 9362 into the 'reut2' index.
# Inserted document 9363 into the 'reut2' index.
# Inserted document 9364 into the 'reut2' index.
# Inserted document 9365 into the 'reut2' index.
# Inserted document 9366 into the 'reut2' index.
# Inserted document 9367 into the 'reut2' index.
# Inserted document 9368 into the 'reut2' index.
# Inserted document 9369 into the 'reut2' index.
# Inserted document 9370 into the 'reut2' index.
# Inserted document 9371 into the 'reut2' index.
# Inserted document 9372 into the 'reut2' index.
# Inserted document 9373 into the 'reut2' index.
# Inserted document 9374 into the 'reut2' index.
# Inserted document 9375 into the 'reut2' index.
# Inserted document 9376 into the 'reut2' index.
# Inserted document 9377 into the 'reut2' index.
# Inserted document 9378 into the 'reut2' index.
# Inserted document 9379 into the 'reut2' index.
# Inserted document 9380 into the 'reut2' index.
# Inserted document 9381 into the 'reut2' index.
# Inserted document 9382 into the 'reut2' index.
# Inserted document 9383 into the 'reut2' index.
# Inserted document 9384 into the 'reut2' index.
# Inserted document 9385 into the 'reut2' index.
# Inserted document 9386 into the 'reut2' index.
# Inserted document 9387 into the 'reut2' index.
# ObjectApiResponse({'_shards': {'total': 2, 'successful': 1, 'failed': 0}})
